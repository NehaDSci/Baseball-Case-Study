# %% [markdown]
# # Baseball Case Study

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# We can see here little information of data thats shows 5 rows and all present columns in
#
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# Output: Number of predicted wins (W)

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %% [markdown]
# We can see here little information of data thats shows 5 rows and all present in columns

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# Here, it the all the data of baseball which  shows all rows and all present in columns

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# here, we can see data having 30 no. of rows and 17 no of columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# it shows all the datatypes of data, there is an int value except ERA,it has only float value

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# it shows all the columns of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Here we can se information of data according to this data having float64(1), int64(16) no of columns

# %%
# checking null values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there is no missing values

# %%
# checking outliers
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no null values

# %%
# Summary statistics
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# in the summary statistics it has All numerical features and some of the features are not normaly distributed

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats 
import warnings
warnings.filterwarnings('ignore')

# %%
corr=df.corr()
corr
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
sns.pairplot(df,size=1,kind='kde')

# %% [markdown]
#  in the above chart we cann see the pair of all the data

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr, cmap="Accent", annot=True, linewidth=0.3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# R,AB,H,ZB,HR,SV they are highly correlated with each other

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# in this chart it is showing,it is highly correlated with each other

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# it this chart it is showing,it is lightly correlated with each other but RA, ER, ERA columns are highly correlated with each other. and also These columns are are highly negatively correlated with W(wins) columns that means there is high imapact of these columns on wining.
# We are dropping two columns [RA, ER] and keeping ERA(earned runs average column from them because these have same kind of effect on wins, wonts affect the prediction model

# %%
df.drop(['RA','ER'], axis=1,inplace=True)

# %%
df.shape
# Out:
# (30, 15)

# %% [markdown]
# After dropping two columns we have 15 columns left in data

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We have ERA left in data which negatively correlated with data.and we can see here data is not that much correlated with wins.Also can be noticed ERA is correlated with SV and SHO columns

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['ERA'],c='Red')
plt.xlabel('wins')
plt.ylabel('Earned run average')
plt.show()

# %% [markdown]
# We can see here we have less Earned Run Average in there we have more wins matches.In 65 to 88 wins we have average 4 to 5 runs
# In 90 to 100 wins we can see we have average of 3 to 4 runs

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['SV'],c='Red')
plt.xlabel('wins')
plt.ylabel('Saves')
plt.show()

# %% [markdown]
# We can notice here saves having effect on wins whenever saves increasing that also giving the high to be win

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['SHO'],c='Red')
plt.xlabel('wins')
plt.ylabel('shutouts')
plt.show()

# %% [markdown]
# Shutouts has a little effect on data in some of data we see whenever shutouts is high there is a chance of win

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['BB'],c='Green')
plt.xlabel('wins')
plt.ylabel('Walks')
plt.show()

# %% [markdown]
# There we also see when the walks is high matches wins is also incresing

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['2B'],c='Green')
plt.xlabel('wins')
plt.ylabel('Doubles')
plt.show()

# %% [markdown]
# Doubles are also helping in wins when there is high no of doubles in match wining is also increasing

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['W'],df['R'],c='Blue')
plt.xlabel('wins')
plt.ylabel('runs')
plt.show()

# %% [markdown]
# There we dont that much effect on data most of runs are in 600 to 800 in all wining matchs, some of outliers we also see in this

# %% [markdown]
# ## Checking Outliers

# %%
plt.figure(figsize=(18,10))
for o in enumerate(df):
    plt.subplot(3,5,o[0]+1)
    sns.boxplot(df[o[1]])

# %% [markdown]
# We can see here only 5 columns are there we have outliers in data (R, ERA, SHO, SV, E)

# %% [markdown]
# ## Removing Outliers

# %% [markdown]
# ### ZSCore Method

# %%
#zscore

from scipy.stats import zscore

z=np.abs(zscore(df))

print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
z[5][1]
# Out:
# 3.5096470447193067

# %%
df_new=df[(z<3).all(axis=1)]
print("with outliers::",df.shape)
print("After removing outliers::",df_new.shape)
# Out:
# with outliers:: (30, 15)
# After removing outliers:: (29, 15)

# %% [markdown]
# We can see here only 1 row have been removed by ZSCORE

# %% [markdown]
# ### Using IQR Method

# %%
#IQR
from scipy import stats 
IQR = stats.iqr(df) 
IQR
# Out:
# 614.25

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

# %%
df_out = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
print(df_out.shape)
# Out:
# (30, 15)

# %% [markdown]
# with IQR method there is no outliers which logical possible because of very less amount of data

# %% [markdown]
# #### We are taking ZSCORE method we are not dealing outliers anymore because there is very less data

# %%
df=df_new

# %%
df.shape
# Out:
# (29, 15)

# %%
plt.boxplot(df['R'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x238b660dd90>,
#   <matplotlib.lines.Line2D at 0x238b661f130>],
#  'caps': [<matplotlib.lines.Line2D at 0x238b661f490>,
#   <matplotlib.lines.Line2D at 0x238b661f7f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x238b660da30>],
#  'medians': [<matplotlib.lines.Line2D at 0x238b661fb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x238b661feb0>],
#  'means': []}

# %% [markdown]
# We can see here the outliers have been removed from 'R' column

# %%
plt.boxplot(df['ERA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x238b6677580>,
#   <matplotlib.lines.Line2D at 0x238b66778e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x238b6677c40>,
#   <matplotlib.lines.Line2D at 0x238b6677fa0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x238b6677280>],
#  'medians': [<matplotlib.lines.Line2D at 0x238b6681340>],
#  'fliers': [<matplotlib.lines.Line2D at 0x238b66816a0>],
#  'means': []}

# %% [markdown]
# We can see here the outliers have been removed from 'ERA' column

# %% [markdown]
# ## Skewness Handling

# %%
plt.figure(figsize=(25,20))
for i in enumerate(df.columns):
    plt.subplot(5,3,i[0]+1)
    sns.distplot(df[i[1]],color='r')

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# We can see here there are some data skewed in column(H, CG, SHO, SV, E)

# %% [markdown]
# #### skewness more than+/- 0.5 will we treated Here we are removing skewness from Columns(H, CG, SHO, SV, E)

# %%
from sklearn.preprocessing import power_transform
df[['H', 'CG', 'SHO', 'SV', 'E']]=power_transform(df[['H', 'CG', 'SHO', 'SV', 'E']],method='yeo-johnson')

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.000000
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# here, we can see that skewness is almost removed from every column

# %% [markdown]
# ## Dividing data into X and Y

# %%
x=df.drop(['W'],axis=1)
y=df['W']

# %%
x.shape
# Out:
# (29, 14)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# ## Scaling X Values

# %%
from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
x=sc.fit_transform(x)

# %%
pd.DataFrame(x).describe()
# Out:
#               0          1     2          3          4          5          6   \
# count  29.000000  29.000000  29.0  29.000000  29.000000  29.000000  29.000000
# mean    0.566709   0.498171   0.0   0.560988   0.522031   0.471353   0.471983
# std     0.237471   0.271595   0.0   0.257760   0.285448   0.227698   0.285046
# min     0.000000   0.000000   0.0   0.000000   0.000000   0.000000   0.000000
# 25%     0.403141   0.295455   0.0   0.388060   0.361111   0.307692   0.265625
# 50%     0.607330   0.477273   0.0   0.567164   0.527778   0.430769   0.500000
# 75%     0.732984   0.704545   0.0   0.776119   0.722222   0.592308   0.630208
# max     1.000000   1.000000   0.0   1.000000   1.000000   1.000000   1.000000
#
#               7          8          9          10         11         12  \
# count  29.000000  29.000000  29.000000  29.000000  29.000000  29.000000
# mean    0.511104   0.437165   0.486535   0.462820   0.496773   0.545151
# std     0.190697   0.257811   0.219594   0.271806   0.244940   0.222023
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.341284   0.277778   0.347619   0.230279   0.373171   0.400262
# 50%     0.533945   0.433333   0.519048   0.495369   0.553751   0.556566
# 75%     0.622018   0.588889   0.619048   0.668644   0.609418   0.666996
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               13
# count  29.000000
# mean    0.508101
# std     0.276493
# min     0.000000
# 25%     0.361169
# 50%     0.508619
# 75%     0.612261
# max     1.000000

# %%
x.shape
# Out:
# (29, 14)

# %% [markdown]
# ### Splitting the data for training and testing

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### CHECKING THE BEST RANDOM STATE FOR DATA SPLIT

# %%
from sklearn.linear_model import LinearRegression


LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state {i}, The training accuracy is: {r2_score(y_train,LR_predict_train)}')
    print(f'At random state {i}, The test accuracy is: {r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state 0, The training accuracy is: 0.9736906586984252
# At random state 0, The test accuracy is: 0.4693395717817508
#
#
# At random state 1, The training accuracy is: 0.9571826105045791
# At random state 1, The test accuracy is: 0.7871492501259465
#
#
# At random state 2, The training accuracy is: 0.9502780220264988
# At random state 2, The test accuracy is: 0.05599264303147622
#
#
# At random state 3, The training accuracy is: 0.9399599735491632
# At random state 3, The test accuracy is: 0.8881657604703698
#
#
# At random state 4, The training accuracy is: 0.9517384585759202
# At random state 4, The test accuracy is: 0.8356032194388249
#
#
# At random state 5, The training accuracy is: 0.9537788327320602
# At random state 5, The test accuracy is: 0.6097483835148074
#
#
# At random state 6, The training accuracy is: 0.9283025731276062
# At random state 6, The test accuracy is: 0.9464156224630756
#
#
# At random state 7, The training accuracy is: 0.9510165544533934
# At random state 7, The test accuracy is: 0.7206146164227605
#
#
# At random state 8, The training accuracy is: 0.9665939300206474
# At random state 8, The test accuracy is: 0.7893097306467383
#
#
# At random state 9, The training accuracy is: 0.9777528070936349
# At random state 9, The test accuracy is: 0.5290481382175041
#
#
# At random state 10, The training accuracy is: 0.9680872250092353
# At random state 10, The test accuracy is: 0.4844688099920038
#
#
# At random state 11, The training accuracy is: 0.9584020561734781
# At random state 11, The test accuracy is: 0.24782898013588406
#
#
# At random state 12, The training accuracy is: 0.9693382701338243
# At random state 12, The test accuracy is: 0.6349906908701677
#
#
# At random state 13, The training accuracy is: 0.9489699363073404
# At random state 13, The test accuracy is: 0.8520885359215797
#
#
# At random state 14, The training accuracy is: 0.9473983873805651
# At random state 14, The test accuracy is: 0.8830864509105456
#
#
# At random state 15, The training accuracy is: 0.9273118769339455
# At random state 15, The test accuracy is: 0.9451099855628845
#
#
# At random state 16, The training accuracy is: 0.9676073969552134
# At random state 16, The test accuracy is: 0.503773449968779
#
#
# At random state 17, The training accuracy is: 0.9435622074428833
# At random state 17, The test accuracy is: 0.7775106097028643
#
#
# At random state 18, The training accuracy is: 0.9686282576632164
# At random state 18, The test accuracy is: 0.2617181061407665
#
#
# At random state 19, The training accuracy is: 0.9600332883420296
# At random state 19, The test accuracy is: 0.2225811397865768
#
#
# At random state 20, The training accuracy is: 0.9630109977664184
# At random state 20, The test accuracy is: 0.11889910444888152
#
#
# At random state 21, The training accuracy is: 0.9658957862114006
# At random state 21, The test accuracy is: 0.5387807626638732
#
#
# At random state 22, The training accuracy is: 0.9538769562129328
# At random state 22, The test accuracy is: 0.6473930369269981
#
#
# At random state 23, The training accuracy is: 0.9836574799435106
# At random state 23, The test accuracy is: 0.16486690723034314
#
#
# At random state 24, The training accuracy is: 0.9524770125928675
# At random state 24, The test accuracy is: 0.0592615997151098
#
#
# At random state 25, The training accuracy is: 0.9532865456034552
# At random state 25, The test accuracy is: 0.5202775001654937
#
#
# At random state 26, The training accuracy is: 0.9628746268037044
# At random state 26, The test accuracy is: 0.09911388604303484
#
#
# At random state 27, The training accuracy is: 0.9708245046757874
# At random state 27, The test accuracy is: 0.7405341861366388
#
#
# At random state 28, The training accuracy is: 0.9621519696601404
# At random state 28, The test accuracy is: 0.6322715657865632
#
#
# At random state 29, The training accuracy is: 0.9413588099461153
# At random state 29, The test accuracy is: 0.9074709402197773
#
#
# At random state 30, The training accuracy is: 0.9490607184887702
# At random state 30, The test accuracy is: 0.8592991142258025
#
#
# At random state 31, The training accuracy is: 0.9702047723144877
# At random state 31, The test accuracy is: 0.30820124875496335
#
#
# At random state 32, The training accuracy is: 0.9699247678240163
# At random state 32, The test accuracy is: 0.31788078739799586
#
#
# At random state 33, The training accuracy is: 0.9562965454974548
# At random state 33, The test accuracy is: 0.6703068705290113
#
#
# At random state 34, The training accuracy is: 0.9735075568082371
# At random state 34, The test accuracy is: 0.5946889312868209
#
#
# At random state 35, The training accuracy is: 0.9680099126453598
# At random state 35, The test accuracy is: 0.8157637769725388
#
#
# At random state 36, The training accuracy is: 0.9512785714118084
# At random state 36, The test accuracy is: 0.24864922741342965
#
#
# At random state 37, The training accuracy is: 0.9655580229923271
# At random state 37, The test accuracy is: 0.44179696489084186
#
#
# At random state 38, The training accuracy is: 0.954042303642771
# At random state 38, The test accuracy is: 0.5732307934821328
#
#
# At random state 39, The training accuracy is: 0.9719768221392462
# At random state 39, The test accuracy is: 0.37076897182276125
#
#
# At random state 40, The training accuracy is: 0.9658439803241978
# At random state 40, The test accuracy is: 0.40324828669537427
#
#
# At random state 41, The training accuracy is: 0.9499742123064714
# At random state 41, The test accuracy is: 0.7818544181182235
#
#
# At random state 42, The training accuracy is: 0.9456236725100003
# At random state 42, The test accuracy is: 0.8145791998970058
#
#
# At random state 43, The training accuracy is: 0.9744804577267939
# At random state 43, The test accuracy is: 0.1103885747651242
#
#
# At random state 44, The training accuracy is: 0.9536417830638986
# At random state 44, The test accuracy is: 0.6413942102101331
#
#
# At random state 45, The training accuracy is: 0.9689098530268229
# At random state 45, The test accuracy is: 0.5738246433893189
#
#
# At random state 46, The training accuracy is: 0.9405731258620573
# At random state 46, The test accuracy is: 0.8814522302692821
#
#
# At random state 47, The training accuracy is: 0.9273241224083147
# At random state 47, The test accuracy is: 0.9854219282312825
#
#
# At random state 48, The training accuracy is: 0.9652037422450442
# At random state 48, The test accuracy is: 0.5013134510588113
#
#
# At random state 49, The training accuracy is: 0.9580242277211108
# At random state 49, The test accuracy is: 0.012492659645978454
#
#
# At random state 50, The training accuracy is: 0.9371622463364495
# At random state 50, The test accuracy is: 0.8864545674677703
#
#
# At random state 51, The training accuracy is: 0.9683807269190139
# At random state 51, The test accuracy is: 0.6948662144026607
#
#
# At random state 52, The training accuracy is: 0.9712765266479391
# At random state 52, The test accuracy is: 0.542168524476151
#
#
# At random state 53, The training accuracy is: 0.9583495242956814
# At random state 53, The test accuracy is: 0.6151175105657631
#
#
# At random state 54, The training accuracy is: 0.9580943706892957
# At random state 54, The test accuracy is: 0.49400650550330727
#
#
# At random state 55, The training accuracy is: 0.9566335546675676
# At random state 55, The test accuracy is: 0.7596370251922051
#
#
# At random state 56, The training accuracy is: 0.9621576574008731
# At random state 56, The test accuracy is: 0.7147217287982046
#
#
# At random state 57, The training accuracy is: 0.9591636463983159
# At random state 57, The test accuracy is: 0.7617409900065365
#
#
# At random state 58, The training accuracy is: 0.964929927597082
# At random state 58, The test accuracy is: 0.7242711899891525
#
#
# At random state 59, The training accuracy is: 0.962109183541193
# At random state 59, The test accuracy is: 0.7058648671816717
#
#
# At random state 60, The training accuracy is: 0.9807813754931317
# At random state 60, The test accuracy is: 0.5283265583564454
#
#
# At random state 61, The training accuracy is: 0.9715372706122989
# At random state 61, The test accuracy is: 0.6383350967026453
#
#
# At random state 62, The training accuracy is: 0.9724906101700352
# At random state 62, The test accuracy is: 0.5462728793777498
#
#
# At random state 63, The training accuracy is: 0.9796193648658905
# At random state 63, The test accuracy is: 0.6214815949015107
#
#
# At random state 64, The training accuracy is: 0.9434554190784169
# At random state 64, The test accuracy is: 0.8305101746917296
#
#
# At random state 65, The training accuracy is: 0.9638494239991453
# At random state 65, The test accuracy is: 0.4333756457473519
#
#
# At random state 66, The training accuracy is: 0.9511939959829866
# At random state 66, The test accuracy is: 0.8336323494139568
#
#
# At random state 67, The training accuracy is: 0.9459160118124456
# At random state 67, The test accuracy is: 0.8869425925448023
#
#
# At random state 68, The training accuracy is: 0.9467006261280242
# At random state 68, The test accuracy is: 0.8712966302658308
#
#
# At random state 69, The training accuracy is: 0.9520856995762742
# At random state 69, The test accuracy is: 0.4505676906605649
#
#
# At random state 70, The training accuracy is: 0.9514493707180758
# At random state 70, The test accuracy is: 0.4670558662796912
#
#
# At random state 71, The training accuracy is: 0.9807125350451321
# At random state 71, The test accuracy is: -1.3444554303467222
#
#
# At random state 72, The training accuracy is: 0.9472825195778305
# At random state 72, The test accuracy is: 0.735913401878395
#
#
# At random state 73, The training accuracy is: 0.9445653961941514
# At random state 73, The test accuracy is: 0.905726704600293
#
#
# At random state 74, The training accuracy is: 0.9620797836487199
# At random state 74, The test accuracy is: 0.23711231893992535
#
#
# At random state 75, The training accuracy is: 0.92700126745659
# At random state 75, The test accuracy is: 0.9605186564209091
#
#
# At random state 76, The training accuracy is: 0.9621935237523921
# At random state 76, The test accuracy is: 0.5335500387785297
#
#
# At random state 77, The training accuracy is: 0.9598190111876623
# At random state 77, The test accuracy is: 0.5719984453490664
#
#
# At random state 78, The training accuracy is: 0.9454468417761787
# At random state 78, The test accuracy is: 0.8220548646489013
#
#
# At random state 79, The training accuracy is: 0.9580325790959998
# At random state 79, The test accuracy is: 0.808627817106821
#
#
# At random state 80, The training accuracy is: 0.9545503610677599
# At random state 80, The test accuracy is: 0.6737834224140404
#
#
# At random state 81, The training accuracy is: 0.964180970549242
# At random state 81, The test accuracy is: 0.7737006346257445
#
#
# At random state 82, The training accuracy is: 0.9548619037732659
# At random state 82, The test accuracy is: 0.7898287315767824
#
#
# At random state 83, The training accuracy is: 0.965860632603067
# At random state 83, The test accuracy is: 0.37130739313470573
#
#
# At random state 84, The training accuracy is: 0.9481270067690702
# At random state 84, The test accuracy is: 0.8494790414614819
#
#
# At random state 85, The training accuracy is: 0.9393832721375932
# At random state 85, The test accuracy is: 0.8545496255036702
#
#
# At random state 86, The training accuracy is: 0.9551148335785662
# At random state 86, The test accuracy is: 0.13399384587189667
#
#
# At random state 87, The training accuracy is: 0.9410939772654103
# At random state 87, The test accuracy is: 0.7866454145517715
#
#
# At random state 88, The training accuracy is: 0.9698782340792826
# At random state 88, The test accuracy is: -1.0251674235479378
#
#
# At random state 89, The training accuracy is: 0.9454379869850358
# At random state 89, The test accuracy is: 0.8448287709271216
#
#
# At random state 90, The training accuracy is: 0.9523803140705308
# At random state 90, The test accuracy is: 0.7475977853686089
#
#
# At random state 91, The training accuracy is: 0.9815189959708
# At random state 91, The test accuracy is: 0.5172509034203323
#
#
# At random state 92, The training accuracy is: 0.9762226814809365
# At random state 92, The test accuracy is: 0.5072930286131224
#
#
# At random state 93, The training accuracy is: 0.9568988408466734
# At random state 93, The test accuracy is: -0.1794559687374464
#
#
# At random state 94, The training accuracy is: 0.9688239006244456
# At random state 94, The test accuracy is: 0.6446784472311647
#
#
# At random state 95, The training accuracy is: 0.9350770625299197
# At random state 95, The test accuracy is: 0.8652240147892238
#
#
# At random state 96, The training accuracy is: 0.9699100037009849
# At random state 96, The test accuracy is: 0.4461389127083396
#
#
# At random state 97, The training accuracy is: 0.9435510277505881
# At random state 97, The test accuracy is: 0.8618546506706912
#
#
# At random state 98, The training accuracy is: 0.9605408154898329
# At random state 98, The test accuracy is: 0.3814060297711488
#
#
# At random state 99, The training accuracy is: 0.9409461258143584
# At random state 99, The test accuracy is: 0.9333448893206752

# %% [markdown]
# random state=99 giving highest accuracy, choosing that as random state

# %% [markdown]
# #### SPLITTING THE DATA WITH RANDOM STATE =99

# %%
#splitting the data into 78% training and 22% testing
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 14)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 14)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# ## MODEL BUILDING:

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression


LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9411713529485163

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 12.672633550148275
# MAE: 3.274136279060877
# r2_score: 0.8977213310275127

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import Ridge

R=Ridge()
R.fit(x_train,y_train)
print(R.score(x_train,y_train))
R_predict=R.predict(x_test)
# Out:
# 0.7900161919802785

# %%
print('MSE:',mean_squared_error(R_predict,y_test))
print('MAE:',mean_absolute_error(R_predict,y_test))
print('r2_score:',r2_score(R_predict,y_test))
# Out:
# MSE: 49.23918706106377
# MAE: 6.200545498380068
# r2_score: -0.7668782142053798

# %% [markdown]
# ### SVR
#
# ### SVR(kernel='linear')

# %%
from sklearn.svm import SVR

svr=SVR(kernel='linear')
svr.fit(x_train,y_train)
print(svr.score(x_train,y_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.3052809203107092

# %%
print('MSE:',mean_squared_error(svr_predict,y_test))
print('MAE:',mean_absolute_error(svr_predict,y_test))
print('r2_score:',r2_score(svr_predict,y_test))
# Out:
# MSE: 92.33046990756982
# MAE: 8.297178483476788
# r2_score: -15.403272063076379

# %% [markdown]
# ### SVR(kernel='poly')

# %%
svr_p=SVR(kernel='poly')
svr_p.fit(x_train,y_train)
print(svr_p.score(x_train,y_train))
svrpred_p=svr_p.predict(x_test)
# Out:
# 0.9623520035446792

# %%
print('MSE:',mean_squared_error(svrpred_p,y_test))
print('MAE:',mean_absolute_error(svrpred_p,y_test))
print('r2_score:',r2_score(svrpred_p,y_test))
# Out:
# MSE: 25.08245786881002
# MAE: 4.444342971619501
# r2_score: 0.7896849748653556

# %% [markdown]
# ### SVR(kernel='rbf')

# %%
svr_r=SVR(kernel='rbf')
svr_r.fit(x_train,y_train)
print(svr_r.score(x_train,y_train))
svrpred_r=svr_r.predict(x_test)
# Out:
# 0.19209180923383828

# %%
print('MSE:',mean_squared_error(svrpred_r,y_test))
print('MAE:',mean_absolute_error(svrpred_r,y_test))
print('r2_score:',r2_score(svrpred_r,y_test))
# Out:
# MSE: 116.13067806934706
# MAE: 9.435955372289124
# r2_score: -89.25744991027202

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

RF=RandomForestRegressor()
RF.fit(x_train,y_train)
print(RF.score(x_train,y_train))
RF_PRED=RF.predict(x_test)
# Out:
# 0.9445991214197855

# %%
print('MSE:',mean_squared_error(RF_PRED,y_test))
print('MAE:',mean_absolute_error(RF_PRED,y_test))
print('r2_score:',r2_score(RF_PRED,y_test))
# Out:
# MSE: 53.95464285714287
# MAE: 6.7700000000000005
# r2_score: -0.38632470645879424

# %% [markdown]
# ### DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
print(DTR.score(x_train,y_train))
DTR_PRED=DTR.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(DTR_PRED,y_test))
print('MAE:',mean_absolute_error(DTR_PRED,y_test))
print('r2_score:',r2_score(DTR_PRED,y_test))
# Out:
# MSE: 81.0
# MAE: 7.857142857142857
# r2_score: -0.65375

# %% [markdown]
# ### GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
print(GBR.score(x_train,y_train))
GBR_PRED=GBR.predict(x_test)
# Out:
# 0.9999999858489446

# %%
print('MSE:',mean_squared_error(GBR_PRED,y_test))
print('MAE:',mean_absolute_error(GBR_PRED,y_test))
print('r2_score:',r2_score(GBR_PRED,y_test))
# Out:
# MSE: 52.48442089727806
# MAE: 6.414652201674981
# r2_score: -0.03852629640036098

# %% [markdown]
# ### cross validation

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model, x,y):
    rmse =- (cross_val_score(model, x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)


models = [LinearRegression(),
             Ridge(),
             SVR(kernel='linear'),
             SVR(kernel='poly'),
             SVR(kernel='rbf'),
             RandomForestRegressor(),
             DecisionTreeRegressor(),  
             GradientBoostingRegressor(),]
            


names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}    : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR    : 27.033589, 21.860738
# R    : 35.880015, 28.804724
# svr    : 74.591235, 58.448260
# svr_p    : 31.647625, 16.838681
# svr_r    : 95.650187, 68.864422
# RF    : 42.594893, 27.840806
# DTR    : 56.250000, 35.508782
# GBR    : 46.239162, 31.227040

# %% [markdown]
# #### Accourding to all metrics score selecting the LinearRegression as final model

# %% [markdown]
# ## HYPER PARAMETER TUNING:

# %% [markdown]
# ### GridSearchCV

# %% [markdown]
# ### With LinearRegression

# %%
from sklearn.model_selection import GridSearchCV

# %%
LR=LinearRegression()
param={
    'fit_intercept':[True,False],
    'copy_X':[True],
    'n_jobs':[-1],
   'positive' : [True],

}

# %%
LR_grid=GridSearchCV(LinearRegression(),param,cv=4,scoring='accuracy',n_jobs=-1,verbose=2)

# %%
LR_grid.fit(x_train,y_train)
LR_grid_Pred=LR_grid.best_estimator_.predict(x_test)
# Out:
# Fitting 4 folds for each of 2 candidates, totalling 8 fits

# %%
LR_grid.best_estimator_.predict(x_test)
# Out:
# array([76.45621352, 65.09807686, 95.08772745, 84.24426739, 83.10533837,
#        92.65600567, 82.13923134])

# %%
print('MSE:',mean_squared_error(LR_grid_Pred,y_test))
print('MAE:',mean_absolute_error(LR_grid_Pred,y_test))
print('r2_score:',r2_score(LR_grid_Pred,y_test))
# Out:
# MSE: 25.82765799660209
# MAE: 3.7618490017363433
# r2_score: 0.7007977209358373

# %%
LR_grid_Pred
# Out:
# array([76.45621352, 65.09807686, 95.08772745, 84.24426739, 83.10533837,
#        92.65600567, 82.13923134])

# %%
sns.distplot(LR_grid_Pred-y_test)
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
plt.scatter(LR_grid_Pred,y_test)
plt.plot(y_test,y_test,linewidth=4,color='Red')

# %%
print('MSE:',mean_squared_error(LR_grid_Pred,y_test))
print('MAE:',mean_absolute_error(LR_grid_Pred,y_test))
print('r2_score:',r2_score(LR_grid_Pred,y_test))
# Out:
# MSE: 25.82765799660209
# MAE: 3.7618490017363433
# r2_score: 0.7007977209358373

# %% [markdown]
# ## Saving the model

# %%
import joblib

# %%
joblib.dump(LR_grid.best_estimator_,'Baseball Case Study Project.obj')
# Out:
# ['Baseball Case Study Project.obj']

# %%
model=joblib.load('Baseball Case Study Project.obj')

# %%
model.predict(x_test)
# Out:
# array([76.45621352, 65.09807686, 95.08772745, 84.24426739, 83.10533837,
#        92.65600567, 82.13923134])

# %%
print('MSE:',mean_squared_error(LR_grid_Pred,y_test))
print('MAE:',mean_absolute_error(LR_grid_Pred,y_test))
print('r2_score:',r2_score(LR_grid_Pred,y_test))
# Out:
# MSE: 25.82765799660209
# MAE: 3.7618490017363433
# r2_score: 0.7007977209358373
